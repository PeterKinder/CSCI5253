# %%
import pandas as pd
import numpy as np
import argparse
import hashlib
import re

# %%
SOURCE_CSV = 'https://shelterdata.s3.amazonaws.com/shelter1000.csv'

# %%
def sort_columns(data):
    data_copy = data.copy()
    format = "%m/%d/%Y %H:%M:%S %p"
    data_copy['DateTime'] = pd.to_datetime(data_copy['DateTime'], format=format)
    data_copy = data_copy.sort_values(by=['DateTime'], ascending=False).reset_index(drop=True)
    return data_copy

def split_columns(data):
    data_copy = data.copy()
    data_copy[['Neutered', 'Sex']] = data_copy['Sex upon Outcome'].str.split(expand=True)
    data_copy['Year'] = data_copy['DateTime'].dt.year
    data_copy['Month'] = data_copy['DateTime'].dt.month
    data_copy['Day'] = data_copy['DateTime'].dt.day
    return data_copy

def clean_columns(data):
    data_copy = data.copy()
    data_copy = data_copy.apply(lambda col: col.str.lower() if col.dtype == "object" else col)
    data_copy['Name'] = data_copy['Name'].apply(lambda x: re.sub(r'\*', '', str(x)))
    data_copy['Name'] = data_copy['Name'].apply(lambda x: re.sub(r'a\d{6}', 'unknown', str(x)))
    data_copy['Name'] = data_copy['Name'].apply(lambda x: re.sub(r'\d+ grams', 'unknown', str(x)))
    data_copy['Name'] = data_copy['Name'].apply(lambda x: re.sub(r'\d+g', '', str(x)))
    data_copy['Name'] = data_copy['Name'].apply(lambda x: re.sub(r'\s+', ' ', str(x)))
    data_copy['Name'] = data_copy['Name'].apply(lambda x: re.sub(r"^ +| +$", "", str(x)))
    data_copy['Name'] = data_copy['Name'].apply(lambda x: re.sub(r'^\s*$', "unknown", str(x)))
    data_copy['Name'] = data_copy['Name'].replace('nan', 'unknown')
    data_copy['Sex'] = data_copy['Sex'].replace(np.nan, 'unknown')
    data_copy['Outcome Subtype'] = data_copy['Outcome Subtype'].replace(np.nan, 'none')
    data_copy['Neutered'] = data_copy['Neutered'].replace('intact', 'no')
    data_copy['Neutered'] = data_copy['Neutered'].replace(['neutered', 'spayed'], 'yes')
    return data_copy

def drop_columns(data):
    columns = ['MonthYear', 'Age upon Outcome', 'Sex upon Outcome']
    data_copy = data.drop(columns, axis=1, inplace=False)
    return data_copy

def rename_columns(data):
    data_copy = data.copy()
    data_copy.columns = ['animal_natural_key', 'animal_name', 'outcome_date', 'animal_dob', 'outcome_type', 
                         'outcome_type_subtype', 'animal_type', 'animal_breed', 'animal_color', 
                         'outcome_type_neutered', 'animal_sex', 'outcome_date_year', 'outcome_date_month', 
                         'outcome_date_day']
    return data_copy

def prep_data(source_csv):
    data_copy = pd.read_csv(source_csv)
    data_copy = sort_columns(data_copy)
    data_copy = split_columns(data_copy)
    data_copy = clean_columns(data_copy)
    data_copy = drop_columns(data_copy)
    data_copy = rename_columns(data_copy)
    return data_copy

# %%
prepped_data = prep_data(SOURCE_CSV)

# %%
def transform_animal_dim(data):
    data_copy = data[['animal_natural_key', 'animal_name', 'animal_dob', 'animal_type',
                      'animal_breed', 'animal_color', 'animal_sex']].copy()
    surrogate_keys = [hashlib.md5(row.astype(str).str.cat(sep='').encode('utf-8')).hexdigest() for _, row in data_copy.iterrows()]
    data_copy['animal_id'] = surrogate_keys
    data_copy.drop_duplicates(inplace=True)
    data_copy.reset_index(drop=True, inplace=True)
    return surrogate_keys, data_copy    

def transform_date_dim(data):
    data_copy = data[['outcome_date', 'outcome_date_year', 'outcome_date_month', 'outcome_date_day']].copy()
    data_copy['outcome_date'] = data_copy['outcome_date'].dt.date
    surrogate_keys = [hashlib.md5(row.astype(str).str.cat(sep='').encode('utf-8')).hexdigest() for _, row in data_copy.iterrows()]
    data_copy['outcome_date_id'] = surrogate_keys
    data_copy.drop_duplicates(inplace=True)
    data_copy.reset_index(drop=True, inplace=True)
    return surrogate_keys, data_copy

def transform_outcome_dim(data):
    data_copy = data[['outcome_type', 'outcome_type_subtype', 'outcome_type_neutered']].copy()
    surrogate_keys = [hashlib.md5(row.astype(str).str.cat(sep='').encode('utf-8')).hexdigest() for _, row in data_copy.iterrows()]
    data_copy['outcome_date_id'] = surrogate_keys
    data_copy.drop_duplicates(inplace=True)
    data_copy.reset_index(drop=True, inplace=True)
    return surrogate_keys, data_copy

def transform_fact_table(data, animal_keys, date_keys, outcome_keys):
    data_copy = data[['animal_natural_key']].copy()
    data_copy['animal_id'] = animal_keys
    data_copy['outcome_date_id'] = date_keys
    data_copy['outcome_type_id'] = outcome_keys
    return data_copy

def tranform_data(source_csv):
    data = prep_data(source_csv)
    animal_keys, animal_dim = transform_animal_dim(data)
    date_keys, date_dim = transform_date_dim(data)
    outcome_keys, outcome_dim = transform_outcome_dim(data)
    fact_table = transform_fact_table(data, animal_keys, date_keys, outcome_keys)
    return animal_dim, date_dim, outcome_dim, fact_table

# %%
animal_dim, date_dim, outcome_dim, fact_table = tranform_data(SOURCE_CSV)

# %%
animal_dim
# Out:
#     animal_natural_key    animal_name  animal_dob animal_type  \
# 0              a882145         javier  04/16/2023         cat
# 1              a879902          fluff  03/26/2023         cat
# 2              a873253  peach cobbler  07/23/2020         cat
# 3              a876652          gravy  03/17/2023         cat
# 4              a880165        unknown  05/05/2021         cat
# ..                 ...            ...         ...         ...
# 992            a664996        unknown  10/05/2013         dog
# 993            a664661           lily  08/07/2013         cat
# 994            a657197          gecko  05/12/2013         cat
# 995            a662741           todd  08/11/2013         cat
# 996            a664356           azul  03/03/2013         dog
#
#                   animal_breed  animal_color animal_sex  \
# 0           domestic shorthair   brown tabby       male
# 1           domestic shorthair         black     female
# 2         domestic medium hair         black     female
# 3           domestic shorthair    blue tabby       male
# 4           domestic shorthair  orange tabby       male
# ..                         ...           ...        ...
# 992  australian cattle dog mix      tricolor     female
# 993     domestic shorthair mix   black/white     female
# 994     domestic shorthair mix   brown tabby       male
# 995     domestic shorthair mix         black       male
# 996               pit bull mix    blue/white       male
#
#                             animal_id
# 0    858eac5c5c26f77bc549b118cf608abd
# 1    21e1f41948cfccb7a34c3c3a25b658ee
# 2    4d176a54ca0fafadc47f2097559627a4
# 3    61d12eed42cb6e963718c1df41b1ab67
# 4    ee90f154b5d9cc78533780f51686ada9
# ..                                ...
# 992  017b709796dd727b953aa5375ca10d23
# 993  f68ea6838dad3c9cdf9ef8ff579ec617
# 994  281c2698ca896333154c0b993522a16e
# 995  c81202a5bb658e94a1444884014806e8
# 996  7d224d969ddd84e4295702c387a5eb72
#
# [997 rows x 8 columns]

# %%
date_dim
# Out:
#     outcome_date  outcome_date_year  outcome_date_month  outcome_date_day  \
# 0     2023-08-09               2023                   8                 9
# 1     2023-05-28               2023                   5                28
# 2     2023-05-12               2023                   5                12
# 3     2023-05-08               2023                   5                 8
# 4     2023-04-30               2023                   4                30
# ..           ...                ...                 ...               ...
# 841   2013-10-13               2013                  10                13
# 842   2013-10-12               2013                  10                12
# 843   2013-10-09               2013                  10                 9
# 844   2013-10-05               2013                  10                 5
# 845   2013-10-03               2013                  10                 3
#
#                       outcome_date_id
# 0    e868a056913d31b88aa617b85fa647ee
# 1    9c17ed2ce8da701cad89a0ae0439ab12
# 2    c78a198f679d493db4fb7c84491a0024
# 3    cffd23b1522dc992560c5975353b1f92
# 4    2c18754b84525bd31c0651b674f9a40f
# ..                                ...
# 841  b1f669b26d589051c31cf9d12b40ef86
# 842  6bbb031babc07660a32220417325cd4c
# 843  4070f835ed741fcefa8e9114d2c05c4e
# 844  8f7c06a92b0c0f084dc05963f7081e84
# 845  edbdb6192f86dceafb13a245081fa8a9
#
# [846 rows x 5 columns]

# %%
outcome_dim
# Out:
#        outcome_type outcome_type_subtype outcome_type_neutered  \
# 0          adoption               foster                   yes
# 1          adoption                 none                   yes
# 2          transfer                  snr                    no
# 3          transfer              partner                    no
# 4              died            in kennel               unknown
# 5        euthanasia            suffering                    no
# 6          adoption               foster                    no
# 7   return to owner                 none                    no
# 8          adoption                 none               unknown
# 9        euthanasia          rabies risk               unknown
# 10  return to owner                 none                   yes
# 11        rto-adopt                 none                   yes
# 12         transfer            out state                    no
# 13       euthanasia                 none               unknown
# 14             died            in kennel                    no
# 15         disposal                 none                    no
# 16  return to owner                field                    no
# 17             died            emergency                   yes
# 18         transfer              partner                   yes
# 19         transfer            out state                   yes
# 20       euthanasia           aggressive                    no
# 21         adoption              offsite                   yes
# 22         transfer                  snr                   yes
# 23         disposal                 none               unknown
# 24         adoption                 none                    no
# 25       euthanasia            suffering               unknown
# 26       euthanasia               at vet                    no
# 27         transfer              partner               unknown
# 28         transfer                  snr               unknown
# 29             died            in kennel                   yes
# 30       euthanasia            suffering                   yes
# 31  return to owner                 none               unknown
# 32         transfer                 scrp                   yes
# 33         transfer                 scrp                    no
# 34       euthanasia             underage               unknown
# 35       euthanasia          rabies risk                   yes
# 36             died                 none               unknown
# 37         transfer                 scrp               unknown
# 38       euthanasia           aggressive                   yes
# 39             died              enroute                   yes
#
#                      outcome_date_id
# 0   f545dfe47822060f410261b2fc0e5627
# 1   f3b13c8275bc62e819c6fa9875676ac9
# 2   95322443e7081ba69dd2ab5d105cdc80
# 3   092d2cedb9a8e6814813e62f2edfdd8c
# 4   330b21ca186567347d0568830517c104
# 5   ee8e6a873d7b4399c9188c0d565cb308
# 6   8f6a375e703a856ee6006690a9822b21
# 7   1ca4b78972674e3900b5461252d4873b
# 8   cd14131545125e40109ef5691256544a
# 9   ef3266741d2fdd203fdbbef3c6e4e8e1
# 10  e0c0c3766c57e6e17ce67e0019fdacd0
# 11  473c8c036040582c8273f84accd5e681
# 12  dc29e41d72c157c707f02aa0ba8a1b37
# 13  991f9aecd2bd515207f7332610c93f63
# 14  0b2106ee9f881f0f22482552f12f5903
# 15  307c5ef48f38a967a9ab3b9cf96ecd11
# 16  305e00b38b4f09570d85ba6752ecc502
# 17  d89f4daa4ac668dbd4d51b67cf86384c
# 18  5608180e8c3cdad84e77b8b61469245e
# 19  abd5d75fd963182173f7452990118cd8
# 20  6e4c4fe6482ca8eb2e82d3ab5044d83a
# 21  b07e4068d26a09c09aa8ea2337dc55ea
# 22  0a8a61ea5047f43bc17ae7ac53b852b7
# 23  f86b9b94d426cc5c55d8c9137892f62e
# 24  0ec34d612095faad1d8d790c405afa0e
# 25  5852b95f19c9748a6829f5e98eaee625
# 26  8764c7e918dacbca923216651c90b6c6
# 27  c16ee1d17279e187fb5d7950f47cdcf0
# 28  b5c4c2cce1c9ba56f79360c29f780ed4
# 29  f40ad02b2a187a36fa72985a960fc10b
# 30  7662f58b63c83268c27d870ab85cd170
# 31  0256ddcd8a59dae8f82a4a8f98613085
# 32  e2151f4641157bce22672cf55a421c0c
# 33  f72cf2be18c3e56e13950ca8cd18b34a
# 34  70ce95f770e9d20e9357dd22544daa3f
# 35  853bc438ab7cd35db1596dd464ee77d1
# 36  3f48b01eae212faf7707e364d74afd0d
# 37  a7f2c7ad2d3e4368977c3f5c3df8b202
# 38  c8c837842f139648f53845f60777e91f
# 39  52dd5ea0c817b9bf7288518b2d077bc3

# %%
fact_table
# Out:
#     animal_natural_key                         animal_id  \
# 0              a882145  858eac5c5c26f77bc549b118cf608abd
# 1              a879902  21e1f41948cfccb7a34c3c3a25b658ee
# 2              a873253  4d176a54ca0fafadc47f2097559627a4
# 3              a876652  61d12eed42cb6e963718c1df41b1ab67
# 4              a880165  ee90f154b5d9cc78533780f51686ada9
# ..                 ...                               ...
# 995            a664661  f68ea6838dad3c9cdf9ef8ff579ec617
# 996            a664941  948648898aec63b89b95010014aac945
# 997            a657197  281c2698ca896333154c0b993522a16e
# 998            a662741  c81202a5bb658e94a1444884014806e8
# 999            a664356  7d224d969ddd84e4295702c387a5eb72
#
#                       outcome_date_id                   outcome_type_id
# 0    e868a056913d31b88aa617b85fa647ee  f545dfe47822060f410261b2fc0e5627
# 1    9c17ed2ce8da701cad89a0ae0439ab12  f545dfe47822060f410261b2fc0e5627
# 2    9c17ed2ce8da701cad89a0ae0439ab12  f3b13c8275bc62e819c6fa9875676ac9
# 3    c78a198f679d493db4fb7c84491a0024  f3b13c8275bc62e819c6fa9875676ac9
# 4    cffd23b1522dc992560c5975353b1f92  95322443e7081ba69dd2ab5d105cdc80
# ..                                ...                               ...
# 995  b1f669b26d589051c31cf9d12b40ef86  f3b13c8275bc62e819c6fa9875676ac9
# 996  6bbb031babc07660a32220417325cd4c  e0c0c3766c57e6e17ce67e0019fdacd0
# 997  4070f835ed741fcefa8e9114d2c05c4e  f3b13c8275bc62e819c6fa9875676ac9
# 998  8f7c06a92b0c0f084dc05963f7081e84  092d2cedb9a8e6814813e62f2edfdd8c
# 999  edbdb6192f86dceafb13a245081fa8a9  092d2cedb9a8e6814813e62f2edfdd8c
#
# [1000 rows x 4 columns]
