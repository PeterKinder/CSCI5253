# %%
import pandas as pd
from pathlib import Path
from sodapy import Socrata
import datetime

# %%
client = Socrata("data.austintexas.gov", app_token='PKsmnIpUcg9vRfMFeZoUZunC4')

# %%
execution_date = '2023-11-19'
start_date = '2023-11-19'

# %%
execution_date = '2023-11-20'
start_date = '2023-11-19'

# %%
if execution_date == start_date:
    results = client.get("9t4d-g238", where="DateTime <= '{}'".format(start_date), limit=1000000)
else:
    prior_execution_date = (datetime.datetime.strptime(execution_date, '%Y-%m-%d') - datetime.timedelta(days=1)).strftime('%Y-%m-%d')
    results = client.get("9t4d-g238", where="DateTime > '{}' AND DateTime <= '{}'".format(prior_execution_date, execution_date), limit=10000)

# %%
pd.DataFrame(results)
# Out:
#        animal_id        name                 datetime  \
# 0        A794011       Chunk  2019-05-08T18:20:00.000
# 1        A776359       Gizmo  2018-07-18T16:02:00.000
# 2        A821648         NaN  2020-08-16T11:38:00.000
# 3        A720371       Moose  2016-02-13T17:59:00.000
# 4        A674754         NaN  2014-03-18T11:47:00.000
# ...          ...         ...                      ...
# 157142   A859974  *Lady Gaga  2022-08-16T11:42:00.000
# 157143   A856973      *Suede  2022-06-11T15:39:00.000
# 157144   A852036       Queen  2022-03-17T17:22:00.000
# 157145   A852775     A852775  2022-05-18T14:13:00.000
# 157146   A854626     A854626  2022-05-03T16:10:00.000
#
#                       monthyear            date_of_birth outcome_type  \
# 0       2019-05-08T18:20:00.000  2017-05-02T00:00:00.000    Rto-Adopt
# 1       2018-07-18T16:02:00.000  2017-07-12T00:00:00.000     Adoption
# 2       2020-08-16T11:38:00.000  2019-08-16T00:00:00.000   Euthanasia
# 3       2016-02-13T17:59:00.000  2015-10-08T00:00:00.000     Adoption
# 4       2014-03-18T11:47:00.000  2014-03-12T00:00:00.000     Transfer
# ...                         ...                      ...          ...
# 157142  2022-08-16T11:42:00.000  2012-06-21T00:00:00.000     Adoption
# 157143  2022-06-11T15:39:00.000  2021-05-10T00:00:00.000     Adoption
# 157144  2022-03-17T17:22:00.000  2021-12-08T00:00:00.000     Adoption
# 157145  2022-05-18T14:13:00.000  2022-01-31T00:00:00.000     Adoption
# 157146  2022-05-03T16:10:00.000  2022-02-27T00:00:00.000     Adoption
#
#        animal_type sex_upon_outcome age_upon_outcome  \
# 0              Cat    Neutered Male          2 years
# 1              Dog    Neutered Male           1 year
# 2            Other          Unknown           1 year
# 3              Dog    Neutered Male         4 months
# 4              Cat      Intact Male           6 days
# ...            ...              ...              ...
# 157142         Cat    Spayed Female         10 years
# 157143         Cat    Spayed Female           1 year
# 157144         Dog    Spayed Female         3 months
# 157145         Cat    Spayed Female         3 months
# 157146         Cat    Neutered Male         2 months
#
#                                      breed              color outcome_subtype
# 0                   Domestic Shorthair Mix  Brown Tabby/White             NaN
# 1                  Chihuahua Shorthair Mix        White/Brown             NaN
# 2                                  Raccoon               Gray             NaN
# 3       Anatol Shepherd/Labrador Retriever               Buff             NaN
# 4                   Domestic Shorthair Mix       Orange Tabby         Partner
# ...                                    ...                ...             ...
# 157142                           Devon Rex              White             NaN
# 157143                Domestic Medium Hair               Blue             NaN
# 157144                 German Shepherd Mix        Brown/Black             NaN
# 157145            Domestic Medium Hair Mix             Tortie          Foster
# 157146              Domestic Shorthair Mix       Orange Tabby          Foster
#
# [157147 rows x 12 columns]

# %%
pd.DataFrame(results)
# Out:
#    animal_id                 datetime                monthyear  \
# 0    A893305  2023-11-19T10:43:00.000  2023-11-19T10:43:00.000
# 1    A889463  2023-11-19T10:47:00.000  2023-11-19T10:47:00.000
# 2    A892941  2023-11-19T11:00:00.000  2023-11-19T11:00:00.000
# 3    A893088  2023-11-19T11:30:00.000  2023-11-19T11:30:00.000
# 4    A893211  2023-11-19T11:49:00.000  2023-11-19T11:49:00.000
# 5    A893306  2023-11-19T12:27:00.000  2023-11-19T12:27:00.000
# 6    A893191  2023-11-19T12:37:00.000  2023-11-19T12:37:00.000
# 7    A891034  2023-11-19T13:17:00.000  2023-11-19T13:17:00.000
# 8    A885692  2023-11-19T13:27:00.000  2023-11-19T13:27:00.000
# 9    A888964  2023-11-19T14:07:00.000  2023-11-19T14:07:00.000
# 10   A862842  2023-11-19T14:14:00.000  2023-11-19T14:14:00.000
# 11   A881025  2023-11-19T14:28:00.000  2023-11-19T14:28:00.000
# 12   A705625  2023-11-19T14:51:00.000  2023-11-19T14:51:00.000
# 13   A892801  2023-11-19T15:02:00.000  2023-11-19T15:02:00.000
# 14   A853313  2023-11-19T16:14:00.000  2023-11-19T16:14:00.000
# 15   A892123  2023-11-19T17:20:00.000  2023-11-19T17:20:00.000
# 16   A892121  2023-11-19T17:21:00.000  2023-11-19T17:21:00.000
# 17   A873013  2023-11-19T18:03:00.000  2023-11-19T18:03:00.000
#
#               date_of_birth     outcome_type outcome_subtype animal_type  \
# 0   2021-11-19T00:00:00.000       Euthanasia       Suffering         Cat
# 1   2023-08-12T00:00:00.000         Adoption             NaN         Cat
# 2   2020-11-13T00:00:00.000         Adoption             NaN         Cat
# 3   2011-11-15T00:00:00.000         Adoption          Foster         Dog
# 4   2012-11-17T00:00:00.000         Adoption             NaN         Dog
# 5   2013-11-19T00:00:00.000       Euthanasia       Suffering         Cat
# 6   2022-11-16T00:00:00.000         Adoption             NaN         Cat
# 7   2023-09-01T00:00:00.000         Adoption             NaN         Cat
# 8   2021-07-24T00:00:00.000         Adoption             NaN         Dog
# 9   2022-09-15T00:00:00.000         Adoption             NaN         Dog
# 10  2022-06-01T00:00:00.000         Adoption             NaN         Dog
# 11  2017-06-17T00:00:00.000         Adoption             NaN         Dog
# 12  2011-09-23T00:00:00.000  Return to Owner             NaN         Dog
# 13  2023-05-10T00:00:00.000         Adoption             NaN         Cat
# 14  2017-03-16T00:00:00.000         Adoption             NaN         Dog
# 15  2021-11-01T00:00:00.000         Adoption             NaN         Dog
# 16  2021-11-01T00:00:00.000         Adoption             NaN         Dog
# 17  2019-02-05T00:00:00.000         Adoption             NaN         Dog
#
#    sex_upon_outcome age_upon_outcome                               breed  \
# 0     Intact Female             NULL                  Domestic Shorthair
# 1     Neutered Male         3 months                  Domestic Shorthair
# 2     Neutered Male          3 years                            Snowshoe
# 3     Neutered Male         12 years                 Miniature Schnauzer
# 4     Spayed Female         11 years                           Chow Chow
# 5     Intact Female             NULL                  Domestic Shorthair
# 6     Neutered Male           1 year                  Domestic Shorthair
# 7     Intact Female         2 months                  Domestic Shorthair
# 8     Neutered Male          2 years                 German Shepherd Mix
# 9     Spayed Female           1 year                  Labrador Retriever
# 10    Neutered Male           1 year              Labrador Retriever Mix
# 11    Spayed Female          6 years                  Labrador Retriever
# 12    Neutered Male         12 years                        Pit Bull Mix
# 13      Intact Male         6 months                  Domestic Shorthair
# 14    Spayed Female          6 years  American Staffordshire Terrier Mix
# 15    Neutered Male          2 years                  Labrador Retriever
# 16    Neutered Male          2 years                  Labrador Retriever
# 17    Neutered Male          4 years                        Pit Bull Mix
#
#                 color            name
# 0       Calico/Calico             NaN
# 1         Black/White           Akira
# 2    Seal Point/White         *Kodiak
# 3          Buff/Cream             NaN
# 4               Cream       Chowbella
# 5   Brown Tabby/White             NaN
# 6               Black        Bagheera
# 7          Blue/White             NaN
# 8               Black          Gunner
# 9         White/White        *Natalia
# 10          Tan/Black          Cyprus
# 11              Black       *Morticia
# 12        Brown/White            Jack
# 13        Brown Tabby       *Theodore
# 14    Chocolate/White          *Cocoa
# 15              Black        *Kravitz
# 16              Brown        *Crimson
# 17              Black  *Cocoa Pebbles

# %%
def extract(target_dir, target_file, start_date, execution_date):
    if execution_date == start_date:
        results = client.get("9t4d-g238", where="DateTime <= '{}'".format(start_date), limit=1000000)
    else:
        prior_execution_date = (datetime.datetime.strptime(execution_date, '%Y-%m-%d') - datetime.timedelta(days=1)).strftime('%Y-%m-%d')
        results = client.get("9t4d-g238", where="DateTime > '{}' AND DateTime <= '{}'".format(prior_execution_date, execution_date), limit=10000)
    pd.DataFrame(results).to_csv(target_file, index=False)

# %%
datetime.datetime.strptime('2019-05-08T18:20:00.000', '%Y-%m-%dT%H:%M:%S.%f')
# Out:
# datetime.datetime(2019, 5, 8, 18, 20)
